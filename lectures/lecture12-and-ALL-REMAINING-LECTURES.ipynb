# %%
# Click into this cell and press shift-enter before using this notebook.
# This line loads the ability to use %%ai in your file
# %load_ext jupyter_ai_magics
# These lines import the Python modules we commonly use in CMPSC 5A
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots

# %% [markdown]
# # Lecture 12, CMPSC 5A, F25
#
# Tue 11/04/2025, Week 5
#
# # Today's lecture notebook is on Google Colab:
#
# For the rest of the quarter, we'll mostly be working in Google Colab.
#
# Here's why:
# * Access:
#   * You will lose access to your Jupyter Notebook space at the end of the quarter
#   * But you'll have access to your Google Colab files as long as you are affiliated with UCSB
# * Better Integrated AI:
#   * The integration of ChatGPT with Jupyter Hub is a bit of a hack; it breaks often, and can only answer questions you pose to it.
#   * The integration of Gemini into Google Colab is far more seamless; it can help suggest code, and is aware of the contents of your notebook.
# * Easier to Collaborate
#   * While Google Colab does *not* fully, support simultaneous editing in the way that, for example, Google Docs, Sheets and Slides does, it is possible to collaborate on documents together.  This is not currently possible in JupyterHub (though it is a feature that may become available at some point.
#
# So, please consult the link below for today's lecture notebook,
# and all remaining lecture notebooks.
#
# [CS5A-F25-Public (Google Drive folder)](https://drive.google.com/drive/folders/1aBpTNEORz56KTL1gbhrA8_XkSQjicrxL?usp=drive_link)
#
# At this link:
# * Navigate into the folder `lectures`
# * Then select `lecture12.ipynb` or whatever lecture you are looking for.
#
# You can also find this link on Canvas under the heading [Every Lecture Stuff](https://ucsb.instructure.com/courses/27686/modules#module_256404)

# %%
*
